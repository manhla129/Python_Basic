# %%
from tkinter import *



def ccheck1():
    if CheckVar1.get() == 55:
        E1['text'] = '1'
    if CheckVar1.get() == 0:
        E1['text'] = '0'
    TT1['text'] = str(CheckVar1.get() * int(E1['text'])) +',000'
    val = int(var.get())/100
    tongtien['text'] = (CheckVar1.get() * int(E1['text']) + \
    CheckVar2.get() * int(E2['text']) + \
    CheckVar3.get() * int(E3['text']) + \
    CheckVar4.get() * int(E4['text']))
    tongtien['text'] = str(int(round(int(tongtien['text'])*val,0))) + ',000'
    
def ccheck2():
    if CheckVar2.get() == 50:
        E2['text'] = '1'
    if CheckVar2.get() == 0:
        E2['text'] = '0'
    TT2['text'] = str(CheckVar2.get() * int(E2['text'])) +',000'
    val = int(var.get())/100
    tongtien['text'] = (CheckVar1.get() * int(E1['text']) + \
    CheckVar2.get() * int(E2['text']) + \
    CheckVar3.get() * int(E3['text']) + \
    CheckVar4.get() * int(E4['text']))
    tongtien['text'] = str(int(round(int(tongtien['text'])*val,0))) + ',000'
def ccheck3():
    if CheckVar3.get() == 40:
        E3['text'] = '1'
    if CheckVar3.get() == 0:
        E3['text'] = '0'
    TT3['text'] = str(CheckVar3.get() * int(E3['text'])) +',000'
    val = int(var.get())/100
    tongtien['text'] = (CheckVar1.get() * int(E1['text']) + \
    CheckVar2.get() * int(E2['text']) + \
    CheckVar3.get() * int(E3['text']) + \
    CheckVar4.get() * int(E4['text']))
    tongtien['text'] = str(int(round(int(tongtien['text'])*val,0))) + ',000'
def ccheck4():
    if CheckVar4.get() == 10:
        E4['text'] = '1'
    if CheckVar4.get() == 0:
        E4['text'] = '0'
    TT4['text'] = str(CheckVar4.get() * int(E4['text'])) +',000'
    val = int(var.get())/100
    tongtien['text'] = (CheckVar1.get() * int(E1['text']) + \
    CheckVar2.get() * int(E2['text']) + \
    CheckVar3.get() * int(E3['text']) + \
    CheckVar4.get() * int(E4['text']))
    tongtien['text'] = str(int(round(int(tongtien['text'])*val,0))) + ',000'
    
def b11press(event):
    try:
        if int(E1['text']) >0:
            E1['text'] = str(int(E1['text']) - 1)
        TT1['text'] = str(CheckVar1.get() * int(E1['text'])) +',000'
        val = int(var.get())/100
        tongtien['text'] = (CheckVar1.get() * int(E1['text']) + \
        CheckVar2.get() * int(E2['text']) + \
        CheckVar3.get() * int(E3['text']) + \
        CheckVar4.get() * int(E4['text']))
        tongtien['text'] = str(int(round(int(tongtien['text'])*val,0))) + ',000'
    except:
        pass
def b22press(event):
    try:
        if int(E2['text']) >0:
            E2['text'] = str(int(E2['text']) - 1)
        TT2['text'] = str(CheckVar2.get() * int(E2['text'])) +',000'
        val = int(var.get())/100
        tongtien['text'] = (CheckVar1.get() * int(E1['text']) + \
        CheckVar2.get() * int(E2['text']) + \
        CheckVar3.get() * int(E3['text']) + \
        CheckVar4.get() * int(E4['text']))
        tongtien['text'] = str(int(round(int(tongtien['text'])*val,0))) + ',000'
    except:
        pass
def b33press(event):
    try:
        if int(E3['text']) >0:
            E3['text'] = str(int(E3['text']) - 1)
        TT3['text'] = str(CheckVar3.get() * int(E3['text'])) +',000'
        tongtien['text'] = (CheckVar1.get() * int(E1['text']) + \
        CheckVar2.get() * int(E2['text']) + \
        CheckVar3.get() * int(E3['text']) + \
        CheckVar4.get() * int(E4['text']))*1000
    except:
        pass
def b44press(event):
    try:
        if int(E4['text']) >0:
            E4['text'] = str(int(E4['text']) - 1)
        TT4['text'] = str(CheckVar4.get() * int(E4['text'])) +',000'
        val = int(var.get())/100
        tongtien['text'] = (CheckVar1.get() * int(E1['text']) + \
        CheckVar2.get() * int(E2['text']) + \
        CheckVar3.get() * int(E3['text']) + \
        CheckVar4.get() * int(E4['text']))
        tongtien['text'] = str(int(round(int(tongtien['text'])*val,0))) + ',000'
    except:
        pass
    
def b1press(event):
    try:
        E1['text'] = str(int(E1['text']) + 1)
        TT1['text'] = str(CheckVar1.get() * int(E1['text'])) +',000'
        val = int(var.get())/100
        tongtien['text'] = (CheckVar1.get() * int(E1['text']) + \
        CheckVar2.get() * int(E2['text']) + \
        CheckVar3.get() * int(E3['text']) + \
        CheckVar4.get() * int(E4['text']))
        tongtien['text'] = str(int(round(int(tongtien['text'])*val,0))) + ',000'
    except:
        pass
def b2press(event):
    try:
        E2['text'] = str(int(E2['text']) + 1)
        TT2['text'] = str(CheckVar2.get() * int(E2['text'])) +',000'
        val = int(var.get())/100
        tongtien['text'] = (CheckVar1.get() * int(E1['text']) + \
        CheckVar2.get() * int(E2['text']) + \
        CheckVar3.get() * int(E3['text']) + \
        CheckVar4.get() * int(E4['text']))
        tongtien['text'] = str(int(round(int(tongtien['text'])*val,0))) + ',000'
    except:
        pass
def b3press(event):
    try:
        E3['text'] = str(int(E3['text']) + 1)
        TT3['text'] = str(CheckVar3.get() * int(E3['text'])) +',000'
        val = int(var.get())/100
        tongtien['text'] = (CheckVar1.get() * int(E1['text']) + \
        CheckVar2.get() * int(E2['text']) + \
        CheckVar3.get() * int(E3['text']) + \
        CheckVar4.get() * int(E4['text']))
        tongtien['text'] = str(int(round(int(tongtien['text'])*val,0))) + ',000'
    except:
        pass
def b4press(event):
    try:
        E4['text'] = str(int(E4['text']) + 1)
        TT4['text'] = str(CheckVar4.get() * int(E4['text'])) +',000'
        val = int(var.get())/100
        tongtien['text'] = (CheckVar1.get() * int(E1['text']) + \
        CheckVar2.get() * int(E2['text']) + \
        CheckVar3.get() * int(E3['text']) + \
        CheckVar4.get() * int(E4['text']))
        tongtien['text'] = str(int(round(int(tongtien['text'])*val,0))) + ',000'
    except:
        pass 
    
def selection():
    val = int(var.get())/100
    tongtien['text'] = (CheckVar1.get() * int(E1['text']) + \
        CheckVar2.get() * int(E2['text']) + \
        CheckVar3.get() * int(E3['text']) + \
        CheckVar4.get() * int(E4['text']))
    tongtien['text'] = str(int(round(int(tongtien['text'])*val,0))) + ',000'
    
color1 = '#0fbcee'
root = Tk()
root.geometry('550x400')
root.title('Bảng thanh toán')
root['background'] = color1

menu = LabelFrame(root, text='Bảng giá', width=530, height=200, font=('Arial',16))
menu['background'] = color1
menu.place(x=10, y=10)

name = Label(menu, text='Menu',font=('Arial',12))
name['background'] = color1
name.place(x=12, y=5)

CheckVar1 = IntVar()
CheckVar2 = IntVar()
CheckVar3 = IntVar()
CheckVar4 = IntVar()

C1 = Checkbutton(menu, anchor=W, text='Bún bò Huế',onvalue=55, offvalue=0, variable=CheckVar1, command=ccheck1)
C2 = Checkbutton(menu, anchor=W, text='Bún chả',onvalue=50, offvalue=0, variable=CheckVar2, command=ccheck2)
C3 = Checkbutton(menu, anchor=W, text='Bún đậu',onvalue=40, offvalue=0, variable=CheckVar3, command=ccheck3)
C4 = Checkbutton(menu, anchor=W, text='Trà đá',onvalue=10, offvalue=0, variable=CheckVar4, command=ccheck4)

C1.place(x=14, y=40)
C2.place(x=14, y=70)
C3.place(x=14, y=100)
C4.place(x=14, y=130)
C1['background'] = color1
C2['background'] = color1
C3['background'] = color1
C4['background'] = color1

giatien = Label(menu, text='Giá',font=('Arial',12))
giatien['background'] = color1
giatien.place(x=145, y=5)

L1 = Label(menu, text='55.000/bát')
L2 = Label(menu, text='50.000/bát')
L3 = Label(menu, text='40.000/bát')
L4 = Label(menu, text='10.000/cốc')
L1.place(x=150, y=40)
L2.place(x=150, y=70)
L3.place(x=150, y=100)
L4.place(x=150, y=130)
L1['background'] = color1
L2['background'] = color1
L3['background'] = color1
L4['background'] = color1

soluong = Label(menu, text='Số lượng',font=('Arial',12))
soluong['background'] = color1
soluong.place(x=280, y=5)

E1 = Label(menu, text='0', width=4)
E2 = Label(menu, text='0', width=4)
E3 = Label(menu, text='0', width=4)
E4 = Label(menu, text='0', width=4)
E1.place(x=265, y=40)
E2.place(x=265, y=70)
E3.place(x=265, y=100)
E4.place(x=265, y=130)

B11 = Button(menu, text='-', width=2)
B22 = Button(menu, text='-', width=2)
B33 = Button(menu, text='-', width=2)
B44 = Button(menu, text='-', width=2)
B11.place(x=310, y=37)
B22.place(x=310, y=68)
B33.place(x=310, y=98)
B44.place(x=310, y=128)
B11.bind('<Button-1>',b11press)
B22.bind('<Button-1>',b22press)
B33.bind('<Button-1>',b33press)
B44.bind('<Button-1>',b44press)

B1 = Button(menu, text='+', width=2)
B2 = Button(menu, text='+', width=2)
B3 = Button(menu, text='+', width=2)
B4 = Button(menu, text='+', width=2)
B1.place(x=340, y=37)
B2.place(x=340, y=68)
B3.place(x=340, y=98)
B4.place(x=340, y=128)
B1.bind('<Button-1>',b1press)
B2.bind('<Button-1>',b2press)
B3.bind('<Button-1>',b3press)
B4.bind('<Button-1>',b4press)

thanhtien = Label(menu, text='Thành tiền',font=('Arial',12))
thanhtien['background'] = color1
thanhtien.place(x=400, y=5)

TT1 = Label(menu, text='0')
TT2 = Label(menu, text='0')
TT3 = Label(menu, text='0')
TT4 = Label(menu, text='0')
TT1.place(x=400, y=40)
TT2.place(x=400, y=70)
TT3.place(x=400, y=100)
TT4.place(x=400, y=130)
TT1['background'] = color1
TT2['background'] = color1
TT3['background'] = color1
TT4['background'] = color1

color2 = '#f0c43b'
phuongthuc = LabelFrame(root, text='Phương thức thanh toán', width=530, height=70, font=('Arial',16))
phuongthuc['background'] = color2
phuongthuc.place(x=10, y=220)

var = IntVar()
var.set(100)
rd1 = Radiobutton(phuongthuc, text='Tiền mặt (-5%)', variable=var, value=95, command=selection)
rd2 = Radiobutton(phuongthuc, text='Chuyển khoản (+5%)', variable=var, value=105, command=selection)
rd1.place(x=10, y=10)
rd2.place(x=150, y=10)
rd1['background'] = color2
rd2['background'] = color2

color3 = '#04c050'
output = LabelFrame(root, text='Tổng tiền', width=530, height=90, font=('Arial',16))
output['background'] = color3
output.place(x=10, y=300)

tongtien = Label(output,text='0',font=('Arial',25), width=15,anchor=E)
tongtien.place(x=220, y=10)
root.mainloop()
