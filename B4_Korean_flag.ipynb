# %%
# khai báo thư viện, điều chỉnh thông số
import turtle
tl = turtle.Turtle()
tl.shape('turtle')
tl.speed(10)


# Vẽ hình tròn vô cực
tl.fillcolor('red')
tl.begin_fill()
tl.right(120)
tl.circle(60, -180)
tl.circle(120, 180)
tl.circle(60,  180)
tl.end_fill()

tl.fillcolor('blue')
tl.begin_fill()
tl.circle(60, -180)
tl.circle(120, 180)
tl.circle(60,  180)
tl.end_fill()

# Vẽ 3 vạch đen dưới/trái
tl.right(15)
tl.penup()
tl.forward(180)
tl.right(90)
tl.backward(50)
tl.pendown()
tl.fillcolor('black')
tl.begin_fill()
tl.forward(100)
tl.left(90)
tl.forward(10)
tl.left(90)
tl.forward(100)
tl.left(90)
tl.forward(10)
tl.end_fill()

tl.penup()
tl.backward(20)
tl.pendown()
tl.fillcolor('black')
tl.begin_fill()
tl.left(90)
tl.forward(100)
tl.left(90)
tl.forward(10)
tl.left(90)
tl.forward(100)
tl.left(90)
tl.forward(10)
tl.end_fill()

tl.penup()
tl.backward(20)
tl.pendown()
tl.fillcolor('black')
tl.begin_fill()
tl.left(90)
tl.forward(100)
tl.left(90)
tl.forward(10)
tl.left(90)
tl.forward(100)
tl.left(90)
tl.forward(10)
tl.end_fill()

tl.penup()
tl.forward(20)
tl.left(90)
tl.forward(45)
tl.pendown()
tl.pencolor('white')
tl.fillcolor('white')
tl.begin_fill()
tl.forward(10)
tl.left(90)
tl.forward(10)
tl.left(90)
tl.forward(10)
tl.left(90)
tl.forward(10)
tl.end_fill()

tl.penup()
tl.pencolor('black')
tl.left(90)
tl.forward(5)
tl.right(90)
tl.forward(210)

# vẽ 3 vạch đen trên/phải
tl.forward(190)
tl.left(90)
tl.backward(50)
tl.pendown()
tl.fillcolor('black')
tl.begin_fill()
tl.forward(100)
tl.left(90)
tl.forward(10)
tl.left(90)
tl.forward(100)
tl.left(90)
tl.forward(10)
tl.end_fill()

tl.penup()
tl.forward(20)
tl.pendown()
tl.fillcolor('black')
tl.begin_fill()
tl.left(90)
tl.forward(100)
tl.left(90)
tl.forward(10)
tl.left(90)
tl.forward(100)
tl.left(90)
tl.forward(10)
tl.end_fill()

tl.penup()
tl.forward(20)
tl.pendown()
tl.fillcolor('black')
tl.begin_fill()
tl.left(90)
tl.forward(100)
tl.left(90)
tl.forward(10)
tl.left(90)
tl.forward(100)
tl.left(90)
tl.forward(10)
tl.end_fill()

tl.penup()
tl.left(90)
tl.forward(45)
tl.pendown()
tl.pencolor('white')
tl.fillcolor('white')
tl.begin_fill()
tl.forward(10)
tl.left(90)
tl.forward(10)
tl.left(90)
tl.forward(10)
tl.left(90)
tl.forward(10)
tl.end_fill()

tl.penup()
tl.backward(40)
tl.pendown()
tl.pencolor('white')
tl.fillcolor('white')
tl.begin_fill()
tl.left(90)
tl.forward(10)
tl.left(90)
tl.forward(10)
tl.left(90)
tl.forward(10)
tl.left(90)
tl.forward(10)
tl.end_fill()

tl.penup()
tl.pencolor('black')
tl.left(90)
tl.forward(5)
tl.left(90)
tl.forward(190)

# Vẽ 3 vạch đen trên/trái
tl.right(90)
tl.forward(180)
tl.right(90)
tl.backward(50)
tl.pendown()
tl.fillcolor('black')
tl.begin_fill()
tl.forward(100)
tl.left(90)
tl.forward(10)
tl.left(90)
tl.forward(100)
tl.left(90)
tl.forward(10)
tl.end_fill()

tl.penup()
tl.backward(20)
tl.pendown()
tl.fillcolor('black')
tl.begin_fill()
tl.left(90)
tl.forward(100)
tl.left(90)
tl.forward(10)
tl.left(90)
tl.forward(100)
tl.left(90)
tl.forward(10)
tl.end_fill()

tl.penup()
tl.backward(20)
tl.pendown()
tl.fillcolor('black')
tl.begin_fill()
tl.left(90)
tl.forward(100)
tl.left(90)
tl.forward(10)
tl.left(90)
tl.forward(100)
tl.left(90)
tl.forward(10)
tl.end_fill()

tl.penup()
tl.pencolor('black')
tl.left(90)
tl.forward(50)
tl.right(90)
tl.forward(220)

# Vẽ 3 vạch đen phải/dưới
tl.forward(190)
tl.left(90)
tl.backward(50)
tl.pendown()
tl.fillcolor('black')
tl.begin_fill()
tl.forward(100)
tl.left(90)
tl.forward(10)
tl.left(90)
tl.forward(100)
tl.left(90)
tl.forward(10)
tl.end_fill()

tl.penup()
tl.forward(20)
tl.pendown()
tl.fillcolor('black')
tl.begin_fill()
tl.left(90)
tl.forward(100)
tl.left(90)
tl.forward(10)
tl.left(90)
tl.forward(100)
tl.left(90)
tl.forward(10)
tl.end_fill()

tl.penup()
tl.forward(20)
tl.pendown()
tl.fillcolor('black')
tl.begin_fill()
tl.left(90)
tl.forward(100)
tl.left(90)
tl.forward(10)
tl.left(90)
tl.forward(100)
tl.left(90)
tl.forward(10)
tl.end_fill()

tl.penup()
tl.left(90)
tl.forward(45)
tl.pendown()
tl.pencolor('white')
tl.fillcolor('white')
tl.begin_fill()
tl.forward(10)
tl.left(90)
tl.forward(10)
tl.left(90)
tl.forward(10)
tl.left(90)
tl.forward(10)
tl.end_fill()

tl.penup()
tl.backward(20)
tl.pendown()
tl.pencolor('white')
tl.fillcolor('white')
tl.begin_fill()
tl.left(90)
tl.forward(10)
tl.left(90)
tl.forward(10)
tl.left(90)
tl.forward(10)
tl.left(90)
tl.forward(10)
tl.end_fill()

tl.penup()
tl.backward(20)
tl.pendown()
tl.pencolor('white')
tl.fillcolor('white')
tl.begin_fill()
tl.left(90)
tl.forward(10)
tl.left(90)
tl.forward(10)
tl.left(90)
tl.forward(10)
tl.left(90)
tl.forward(10)
tl.end_fill()

tl.penup()
tl.backward(190)
tl.left(45)
tl.forward(400)
tl.pendown()
tl.pencolor('black')
tl.left(90)
tl.forward(250)
tl.left(90)
tl.forward(800)
tl.left(90)
tl.forward(500)
tl.left(90)
tl.forward(800)
tl.left(90)
tl.forward(250)

# Kết thúc
turtle.done()
