# %%
import turtle
tl = turtle.Turtle()
tl.shape('turtle')
tl.speed(15)

screen = tl.getscreen()
screen.bgcolor('black')

tl.penup()
tl.right(90)
tl.forward(300)
tl.left(90)
tl.forward(200)
tl.pendown()

tl.fillcolor('white')
tl.begin_fill()
tl.circle(100)
tl.end_fill()

tl.left(90)
tl.penup()
tl.forward(170)
tl.right(110)
tl.pendown()
tl.fillcolor('white')
tl.begin_fill()
tl.circle(80)
tl.end_fill()

tl.penup()
tl.right(90)
tl.forward(20)

tl.penup()
tl.forward(20)
tl.pendown()
tl.fillcolor('black')
tl.begin_fill()
tl.circle(5)
tl.end_fill()

tl.penup()
tl.forward(20)
tl.pendown()
tl.fillcolor('black')
tl.begin_fill()
tl.circle(5)
tl.end_fill()

tl.penup()
tl.forward(20)
tl.pendown()
tl.fillcolor('black')
tl.begin_fill()
tl.circle(5)
tl.end_fill()

tl.penup()
tl.backward(90)
tl.left(100)
tl.pendown()
tl.pensize(30)
tl.pencolor('red')
tl.forward(80)
tl.backward(135)
tl.forward(90)
tl.pensize(5)
tl.right(90)
tl.forward(40)
tl.backward(40)

tl.left(90)
tl.forward(20)
tl.right(90)
tl.pensize(15)
tl.forward(60)

tl.penup()
tl.backward(60)
tl.left(90)
tl.backward(50)
tl.left(90)
tl.forward(40)
tl.right(90)
tl.pendown()
tl.pensize(3)
tl.pencolor('black')
tl.fillcolor('black')
tl.begin_fill()
tl.circle(60,30)
tl.circle(60,-60)
tl.end_fill()

tl.left(90)
tl.penup()
tl.forward(30)
tl.right(90)
tl.backward(30)
tl.pendown()
tl.pensize(1)
tl.fillcolor('black')
tl.begin_fill()
tl.circle(10)
tl.end_fill()

tl.penup()
tl.left(30)
tl.forward(70)
tl.pendown()
tl.pensize(1)
tl.fillcolor('black')
tl.begin_fill()
tl.circle(10)
tl.end_fill()

tl.right(30)
tl.penup()
tl.left(90)
tl.forward(40)
tl.right(90)
tl.forward(40)
tl.pendown()
tl.fillcolor('grey')
tl.begin_fill()
tl.forward(10)
tl.left(90)
tl.forward(20)
tl.left(90)
tl.forward(110)
tl.left(90)
tl.forward(20)
tl.left(90)
tl.forward(100)
tl.end_fill()

tl.left(90)
tl.penup()
tl.forward(20)
tl.pendown()
tl.fillcolor('red')
tl.begin_fill()
tl.right(180)
tl.circle(50, -100)
tl.right(25)
tl.circle(100,106)
tl.end_fill()
tl.circle(100,-100)

tl.fillcolor('white')
tl.left(90)
tl.begin_fill()
tl.circle(15,360,10)
tl.end_fill()

tl.pencolor('white')
turtle.color('white')
style = ('Arial', 20, 'italic')
turtle.write('Ok, tôi ổn', move=True, font=style)

tl.penup()
tl.right(30)
tl.forward(700)
tl.pendown()
tl.fillcolor('red')
tl.begin_fill()
tl.forward(100)
tl.left(90)
tl.forward(3)
tl.left(90)
tl.forward(100)
tl.right(90)
tl.forward(5)
tl.left(120)
tl.forward(13)
tl.left(120)
tl.forward(13)
tl.left(120)
tl.forward(5)
tl.right(90)
tl.forward(100)
tl.left(90)
tl.forward(5)
tl.end_fill()

tl.penup()
tl.forward(50)
tl.left(90)
tl.forward(120)
tl.left(180)
tl.left(5)
tl.pendown()
tl.fillcolor('black')
tl.begin_fill()
tl.forward(100)
tl.left(90)
tl.forward(3)
tl.left(90)
tl.forward(100)
tl.right(90)
tl.forward(5)
tl.left(120)
tl.forward(13)
tl.left(120)
tl.forward(13)
tl.left(120)
tl.forward(5)
tl.right(90)
tl.forward(100)
tl.left(90)
tl.forward(5)
tl.end_fill()
tl.right(5)

tl.penup()
tl.backward(110)
tl.left(90)
tl.forward(120)
tl.left(180)
tl.left(-5)
tl.pendown()
tl.fillcolor('green')
tl.begin_fill()
tl.forward(100)
tl.left(90)
tl.forward(3)
tl.left(90)
tl.forward(100)
tl.right(90)
tl.forward(5)
tl.left(120)
tl.forward(13)
tl.left(120)
tl.forward(13)
tl.left(120)
tl.forward(5)
tl.right(90)
tl.forward(100)
tl.left(90)
tl.forward(5)
tl.end_fill()
tl.right(-5)

tl.penup()
tl.backward(70)
tl.left(90)
tl.forward(120)
tl.left(180)
tl.left(-15)
tl.pendown()
tl.fillcolor('yellow')
tl.begin_fill()
tl.forward(100)
tl.left(90)
tl.forward(3)
tl.left(90)
tl.forward(100)
tl.right(90)
tl.forward(5)
tl.left(120)
tl.forward(13)
tl.left(120)
tl.forward(13)
tl.left(120)
tl.forward(5)
tl.right(90)
tl.forward(100)
tl.left(90)
tl.forward(5)
tl.end_fill()
tl.right(-15)

tl.left(15)
tl.penup()
tl.forward(500)
tl.left(90)
tl.pendown()
tl.forward(400)
tl.penup()
tl.forward(100)
tl.pendown()
tl.forward(300)

turtle.done()
